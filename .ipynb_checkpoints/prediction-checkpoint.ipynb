# %%
import duckdb
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

from prophet import Prophet
from prophet.plot import add_changepoints_to_plot
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric

import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
# Sql Config
# %load_ext sql
    
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Connect to duck db 
# %sql duckdb:///powerbi.db

# %%
# Query view with data aggregated for forecast
# %sql df << SELECT * FROM main.salesDataforPrediction WHERE y >= 0 AND ds IS NOT NULL;

# %%
# Add cap variable and column
cap = 40000
df['cap'] = cap

floor = 10
df['floor'] = floor

# Transform in datetime format ds column
df['ds'] = pd.to_datetime(df['ds'])

# %%
# Prophet model
model = Prophet(
    weekly_seasonality = False,
    interval_width = 0.95,
    holidays_prior_scale = 0.1,
    changepoint_prior_scale = 1,
    growth = 'logistic'
)

# Fit model and generatge predictions
model.fit(df)

future = model.make_future_dataframe(periods = 5)
future['cap'] = cap
future['floor'] = floor

forecast = model.predict(future)

# Plot the results and the components of the model
model.plot(forecast)
model.plot_components(forecast)
plt.show()

# %%
# Generate metrics for model analysis
import logging
import contextlib

logging.getLogger('cmdstanpy').setLevel(logging.CRITICAL)

with contextlib.redirect_stdout(None):
    crossValidationDF = cross_validation(
        model,
        horizon = '7 days',
        period = '30 days',
        initial = '366 days',
        parallel = 'processes'
    )

# %%
# Display performance metrics for model
metrics = performance_metrics(crossValidationDF)
metrics.head()
# Out:
#   horizon           mse          rmse           mae      mape     mdape  \
# 0  2 days  2.451111e+08  15656.025848  15656.025848  1.262990  1.262990
# 1  3 days  2.553395e+08  15979.347470  15979.347470  0.362187  0.362187
# 2  4 days  6.385506e+05    799.093633    799.093633  0.027530  0.027530
# 3  5 days  1.276497e+08  11298.215027  11298.215027  0.285222  0.285222
# 4  6 days  3.672013e+07   6059.713980   6059.713980  0.175848  0.175848
#
#       smape  coverage
# 0  0.774131       0.0
# 1  0.442282       0.0
# 2  0.027915       1.0
# 3  0.332664       1.0
# 4  0.192799       1.0

# %%
# Save prediction to duckdb
quantityPrediction = forecast[['ds', 'trend', 'yhat_lower', 'yhat_upper', 'yhat']]

engine = create_engine('duckdb:///powerbi.db')
quantityPrediction.to_sql('quantityPrediction', con = engine, if_exists = 'replace', index = False)
